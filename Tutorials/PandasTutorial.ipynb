# %% [markdown]
# # Pandas Tutorial

# %% [markdown]
# Shouvik Mani <br>
# September 24, 2021 <br>
# COMS 4995: Applied Machine Learning, Columbia University

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 1. DataFrames and Series

# %% [markdown]
# DataFrames and Series are the fundamental data structures of Pandas. A Pandas DataFrame represents a data matrix, but unlike a Numpy matrix, a DataFrame has named columns and rows (indices).
#
# Let's read in a DataFrame from a CSV file. This is a dataset on daily COVID-19 vaccinations by country. Source: https://www.kaggle.com/gpreda/covid-world-vaccination-progress?select=country_vaccinations.csv.

# %%
# Read in a DataFrame from a csv file
vaccine_df = pd.read_csv('data/covid_vaccinations/country_vaccinations.csv')
vaccine_df
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 45979     Zimbabwe      ZWE  2021-09-16           4964302.0
# 45980     Zimbabwe      ZWE  2021-09-17                 NaN
# 45981     Zimbabwe      ZWE  2021-09-18           4992501.0
# 45982     Zimbabwe      ZWE  2021-09-19           5015041.0
# 45983     Zimbabwe      ZWE  2021-09-20           5044809.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# 2                    NaN                      NaN                     NaN
# 3                    NaN                      NaN                     NaN
# 4                    NaN                      NaN                     NaN
# ...                  ...                      ...                     ...
# 45979          2930550.0                2033752.0                108486.0
# 45980                NaN                      NaN                     NaN
# 45981          2940750.0                2051751.0                     NaN
# 45982          2948725.0                2066316.0                 22540.0
# 45983          2961845.0                2082964.0                 29768.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 0                     NaN                            0.00
# 1                  1367.0                             NaN
# 2                  1367.0                             NaN
# 3                  1367.0                             NaN
# 4                  1367.0                             NaN
# ...                   ...                             ...
# 45979             51755.0                           32.89
# 45980             45993.0                             NaN
# 45981             40514.0                           33.08
# 45982             40630.0                           33.23
# 45983             41779.0                           33.43
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                               0.00                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
# ...                              ...                                  ...
# 45979                          19.42                                13.48
# 45980                            NaN                                  NaN
# 45981                          19.49                                13.59
# 45982                          19.54                                13.69
# 45983                          19.63                                13.80
#
#        daily_vaccinations_per_million  \
# 0                                 NaN
# 1                                34.0
# 2                                34.0
# 3                                34.0
# 4                                34.0
# ...                               ...
# 45979                          3429.0
# 45980                          3047.0
# 45981                          2684.0
# 45982                          2692.0
# 45983                          2768.0
#
#                                                 vaccines  \
# 0      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# ...                                                  ...
# 45979  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 45980  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 45981  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 45982  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 45983  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
#
#                      source_name  \
# 0      World Health Organization
# 1      World Health Organization
# 2      World Health Organization
# 3      World Health Organization
# 4      World Health Organization
# ...                          ...
# 45979         Ministry of Health
# 45980         Ministry of Health
# 45981         Ministry of Health
# 45982         Ministry of Health
# 45983         Ministry of Health
#
#                                           source_website
# 0      https://app.powerbi.com/view?r=eyJrIjoiYTkyM2V...
# 1      https://app.powerbi.com/view?r=eyJrIjoiYTkyM2V...
# 2      https://app.powerbi.com/view?r=eyJrIjoiYTkyM2V...
# 3      https://app.powerbi.com/view?r=eyJrIjoiYTkyM2V...
# 4      https://app.powerbi.com/view?r=eyJrIjoiYTkyM2V...
# ...                                                  ...
# 45979  https://www.arcgis.com/home/webmap/viewer.html...
# 45980  https://www.arcgis.com/home/webmap/viewer.html...
# 45981  https://www.arcgis.com/home/webmap/viewer.html...
# 45982  https://www.arcgis.com/home/webmap/viewer.html...
# 45983  https://www.arcgis.com/home/webmap/viewer.html...
#
# [45984 rows x 15 columns]

# %% [markdown]
# Dimensions of DataFrame

# %%
vaccine_df.shape
# Out:
# (45984, 15)

# %% [markdown]
# Type of each column in DataFrame

# %%
vaccine_df.dtypes
# Out:
# country                                 object
# iso_code                                object
# date                                    object
# total_vaccinations                     float64
# people_vaccinated                      float64
# people_fully_vaccinated                float64
# daily_vaccinations_raw                 float64
# daily_vaccinations                     float64
# total_vaccinations_per_hundred         float64
# people_vaccinated_per_hundred          float64
# people_fully_vaccinated_per_hundred    float64
# daily_vaccinations_per_million         float64
# vaccines                                object
# source_name                             object
# source_website                          object
# dtype: object

# %% [markdown]
# Summary statistics for each column

# %%
vaccine_df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        2.508400e+04       2.394600e+04             2.104800e+04
# mean         2.048794e+07       8.757993e+06             5.583303e+06
# std          1.173603e+08       3.430173e+07             2.211721e+07
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          2.077678e+05       1.668525e+05             8.035850e+04
# 50%          1.459863e+06       9.981035e+05             6.352150e+05
# 75%          7.737194e+06       4.679778e+06             3.270408e+06
# max          2.180986e+09       1.100842e+09             1.022207e+09
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            2.060000e+04        4.567700e+04
# mean             2.597850e+05        1.308535e+05
# std              1.317281e+06        8.758538e+05
# min              0.000000e+00        0.000000e+00
# 25%              4.898000e+03        8.710000e+02
# 50%              2.410650e+04        6.774000e+03
# 75%              1.116888e+05        4.169500e+04
# max              2.474100e+07        2.242429e+07
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                    25084.000000                   23946.000000
# mean                        43.740659                      26.569498
# std                         45.044427                      24.458658
# min                          0.000000                       0.000000
# 25%                          5.270000                       4.112500
# 50%                         26.440000                      18.600000
# 75%                         73.442500                      46.300000
# max                        235.390000                     118.270000
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# count                         21048.000000                    45677.000000
# mean                             19.689742                     3547.603520
# std                              21.467135                     4429.261509
# min                               0.000000                        0.000000
# 25%                               2.300000                      505.000000
# 50%                              10.645000                     2191.000000
# 75%                              32.252500                     5307.000000
# max                             117.120000                   117497.000000

# %% [markdown]
# Head and tail of DataFrame

# %%
vaccine_df.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            34.0
# 2                                  NaN                            34.0
# 3                                  NaN                            34.0
# 4                                  NaN                            34.0
#
#                                             vaccines  \
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
#
#                  source_name  \
# 0  World Health Organization
# 1  World Health Organization
# 2  World Health Organization
# 3  World Health Organization
# 4  World Health Organization
#
#                                       source_website
# 0  https://app.powerbi.com/view?r=eyJrIjoiYTkyM2V...
# 1  https://app.powerbi.com/view?r=eyJrIjoiYTkyM2V...
# 2  https://app.powerbi.com/view?r=eyJrIjoiYTkyM2V...
# 3  https://app.powerbi.com/view?r=eyJrIjoiYTkyM2V...
# 4  https://app.powerbi.com/view?r=eyJrIjoiYTkyM2V...

# %%
vaccine_df.tail()
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 45979  Zimbabwe      ZWE  2021-09-16           4964302.0          2930550.0
# 45980  Zimbabwe      ZWE  2021-09-17                 NaN                NaN
# 45981  Zimbabwe      ZWE  2021-09-18           4992501.0          2940750.0
# 45982  Zimbabwe      ZWE  2021-09-19           5015041.0          2948725.0
# 45983  Zimbabwe      ZWE  2021-09-20           5044809.0          2961845.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 45979                2033752.0                108486.0             51755.0
# 45980                      NaN                     NaN             45993.0
# 45981                2051751.0                     NaN             40514.0
# 45982                2066316.0                 22540.0             40630.0
# 45983                2082964.0                 29768.0             41779.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 45979                           32.89                          19.42
# 45980                             NaN                            NaN
# 45981                           33.08                          19.49
# 45982                           33.23                          19.54
# 45983                           33.43                          19.63
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 45979                                13.48                          3429.0
# 45980                                  NaN                          3047.0
# 45981                                13.59                          2684.0
# 45982                                13.69                          2692.0
# 45983                                13.80                          2768.0
#
#                                                 vaccines         source_name  \
# 45979  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  Ministry of Health
# 45980  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  Ministry of Health
# 45981  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  Ministry of Health
# 45982  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  Ministry of Health
# 45983  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  Ministry of Health
#
#                                           source_website
# 45979  https://www.arcgis.com/home/webmap/viewer.html...
# 45980  https://www.arcgis.com/home/webmap/viewer.html...
# 45981  https://www.arcgis.com/home/webmap/viewer.html...
# 45982  https://www.arcgis.com/home/webmap/viewer.html...
# 45983  https://www.arcgis.com/home/webmap/viewer.html...

# %% [markdown]
# A Series represents a column in a DataFrame, and is analogous to a vector. It is also named and has row indices.

# %%
vaccine_df['country']
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
#             ...
# 45979       Zimbabwe
# 45980       Zimbabwe
# 45981       Zimbabwe
# 45982       Zimbabwe
# 45983       Zimbabwe
# Name: country, Length: 45984, dtype: object

# %% [markdown]
# Besides reading in DataFrames and Series from a CSV file, we can also create them from scratch.

# %%
players = ['Lionel Messi', 'Cristiano Ronaldo', 'Neymar', 'Kylian Mbappe', 'Mohamed Salah']
players = pd.Series(players)   # Creates a Series of players
players
# Out:
# 0         Lionel Messi
# 1    Cristiano Ronaldo
# 2               Neymar
# 3        Kylian Mbappe
# 4        Mohamed Salah
# dtype: object

# %%
player_teams = [['Lionel Messi', 'Paris Saint-Germain', 34],
                ['Cristiano Ronaldo', 'Manchester United', 36],
                ['Neymar', 'Paris Saint-Germain', 29],
                ['Kylian Mbappe', 'Paris Saint-Germain', 22],
                ['Mohamed Salah', 'Liverpool', 29]]

# Creates a DataFrame of players, teams, and ages
player_teams_df = pd.DataFrame(player_teams, columns=['Name', 'Team', 'Age'])
player_teams_df
# Out:
#                 Name                 Team  Age
# 0       Lionel Messi  Paris Saint-Germain   34
# 1  Cristiano Ronaldo    Manchester United   36
# 2             Neymar  Paris Saint-Germain   29
# 3      Kylian Mbappe  Paris Saint-Germain   22
# 4      Mohamed Salah            Liverpool   29

# %% [markdown]
# ### 2. Indexing and Iterating

# %% [markdown]
# The index of a DataFrame or Series serves as a (not necessarily unique) identifier for each row. By default, a DataFrame has the index 0, 1, 2, ..., but we can also set the index as we please.

# %%
# Default index is 0, 1, 2, ..., 4
list(player_teams_df.index)
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# Let's set the index of this DataFrame to the player's names.

# %%
player_teams_df = player_teams_df.set_index('Name')
player_teams_df   # now the DataFrame is indexed by player name
# Out:
#                                   Team  Age
# Name
# Lionel Messi       Paris Saint-Germain   34
# Cristiano Ronaldo    Manchester United   36
# Neymar             Paris Saint-Germain   29
# Kylian Mbappe      Paris Saint-Germain   22
# Mohamed Salah                Liverpool   29

# %% [markdown]
# To access an element by it's DataFrame index, use the `.loc` method.

# %%
player_teams_df.loc['Neymar']
# Out:
# Team    Paris Saint-Germain
# Age                      29
# Name: Neymar, dtype: object

# %%
player_teams_df.loc[['Lionel Messi', 'Neymar', 'Kylian Mbappe']]
# Out:
#                               Team  Age
# Name
# Lionel Messi   Paris Saint-Germain   34
# Neymar         Paris Saint-Germain   29
# Kylian Mbappe  Paris Saint-Germain   22

# %% [markdown]
# To access an element by it's numeric index, use the `.iloc`  method.

# %%
player_teams_df.iloc[2]
# Out:
# Team    Paris Saint-Germain
# Age                      29
# Name: Neymar, dtype: object

# %%
player_teams_df.iloc[[2, 3, 4]]
# Out:
#                               Team  Age
# Name
# Neymar         Paris Saint-Germain   29
# Kylian Mbappe  Paris Saint-Germain   22
# Mohamed Salah            Liverpool   29

# %% [markdown]
# We can iterate over a Series using the `.iteritems` method.

# %%
for index, name in players.iteritems():
    print(index, name)
# Out:
# 0 Lionel Messi
# 1 Cristiano Ronaldo
# 2 Neymar
# 3 Kylian Mbappe
# 4 Mohamed Salah

# %% [markdown]
# We can iterate over a DataFrame using the `.iterrows` method.

# %%
for index, row in player_teams_df.iterrows():
    print(index, '\n', row['Team'], '\n', row['Age'], '\n')
# Out:
# Lionel Messi
#  Paris Saint-Germain
#  34
#
# Cristiano Ronaldo
#  Manchester United
#  36
#
# Neymar
#  Paris Saint-Germain
#  29
#
# Kylian Mbappe
#  Paris Saint-Germain
#  22
#
# Mohamed Salah
#  Liverpool
#  29

# %% [markdown]
# ### 3. Filtering and Sorting

# %% [markdown]
# Pandas offers a flexible interface for filtering Series and DataFrames based on various conditions.

# %%
# Filter vaccine_df to rows where country is 'United States'
vaccine_df_usa = vaccine_df[vaccine_df['country'] == 'United States']
print(vaccine_df_usa.shape)
vaccine_df_usa.head()
# Out:
# (275, 15)
#              country iso_code        date  total_vaccinations  \
# 43869  United States      USA  2020-12-20            556208.0
# 43870  United States      USA  2020-12-21            614117.0
# 43871  United States      USA  2020-12-22                 NaN
# 43872  United States      USA  2020-12-23           1008025.0
# 43873  United States      USA  2020-12-24                 NaN
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 43869           556208.0                      NaN                     NaN
# 43870           614117.0                      NaN                 57909.0
# 43871                NaN                      NaN                     NaN
# 43872          1008025.0                      NaN                     NaN
# 43873                NaN                      NaN                     NaN
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 43869                 NaN                            0.17
# 43870             57909.0                            0.18
# 43871            127432.0                             NaN
# 43872            150606.0                            0.30
# 43873            191001.0                             NaN
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 43869                           0.17                                  NaN
# 43870                           0.18                                  NaN
# 43871                            NaN                                  NaN
# 43872                           0.30                                  NaN
# 43873                            NaN                                  NaN
#
#        daily_vaccinations_per_million  \
# 43869                             NaN
# 43870                           172.0
# 43871                           379.0
# 43872                           448.0
# 43873                           568.0
#
#                                         vaccines  \
# 43869  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 43870  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 43871  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 43872  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 43873  Johnson&Johnson, Moderna, Pfizer/BioNTech
#
#                                       source_name  \
# 43869  Centers for Disease Control and Prevention
# 43870  Centers for Disease Control and Prevention
# 43871  Centers for Disease Control and Prevention
# 43872  Centers for Disease Control and Prevention
# 43873  Centers for Disease Control and Prevention
#
#                                           source_website
# 43869  https://covid.cdc.gov/covid-data-tracker/COVID...
# 43870  https://covid.cdc.gov/covid-data-tracker/COVID...
# 43871  https://covid.cdc.gov/covid-data-tracker/COVID...
# 43872  https://covid.cdc.gov/covid-data-tracker/COVID...
# 43873  https://covid.cdc.gov/covid-data-tracker/COVID...

# %%
# Filter vaccine_df to rows where country is 'United States' OR country is 'Mexico'
vaccine_df_usa_mex = vaccine_df[(vaccine_df['country'] == 'United States') | (vaccine_df['country'] == 'Mexico')]
print(vaccine_df_usa_mex.shape)
vaccine_df_usa_mex.head()
# Out:
# (544, 15)
#       country iso_code        date  total_vaccinations  people_vaccinated  \
# 26400  Mexico      MEX  2020-12-24              2924.0             2924.0
# 26401  Mexico      MEX  2020-12-25                 NaN                NaN
# 26402  Mexico      MEX  2020-12-26                 NaN                NaN
# 26403  Mexico      MEX  2020-12-27              6824.0             6824.0
# 26404  Mexico      MEX  2020-12-28              9579.0             9579.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 26400                      NaN                     NaN                 NaN
# 26401                      NaN                     NaN              1300.0
# 26402                      NaN                     NaN              1300.0
# 26403                      NaN                     NaN              1300.0
# 26404                      NaN                  2755.0              1664.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 26400                            0.00                           0.00
# 26401                             NaN                            NaN
# 26402                             NaN                            NaN
# 26403                            0.01                           0.01
# 26404                            0.01                           0.01
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 26400                                  NaN                             NaN
# 26401                                  NaN                            10.0
# 26402                                  NaN                            10.0
# 26403                                  NaN                            10.0
# 26404                                  NaN                            13.0
#
#                                                 vaccines          source_name  \
# 26400  CanSino, Johnson&Johnson, Moderna, Oxford/Astr...  Secretary of Health
# 26401  CanSino, Johnson&Johnson, Moderna, Oxford/Astr...  Secretary of Health
# 26402  CanSino, Johnson&Johnson, Moderna, Oxford/Astr...  Secretary of Health
# 26403  CanSino, Johnson&Johnson, Moderna, Oxford/Astr...  Secretary of Health
# 26404  CanSino, Johnson&Johnson, Moderna, Oxford/Astr...  Secretary of Health
#
#                                           source_website
# 26400  http://www.gob.mx/cms/uploads/attachment/file/...
# 26401  http://www.gob.mx/cms/uploads/attachment/file/...
# 26402  http://www.gob.mx/cms/uploads/attachment/file/...
# 26403  http://www.gob.mx/cms/uploads/attachment/file/...
# 26404  http://www.gob.mx/cms/uploads/attachment/file/...

# %%
# Filter vaccine_df to rows where country is 'United States' AND dates after 2021-01-01
vaccine_df_usa = vaccine_df[(vaccine_df['country'] == 'United States') & (vaccine_df['date'] >= '2021-01-01')]
print(vaccine_df_usa.shape)
vaccine_df_usa.head()
# Out:
# (263, 15)
#              country iso_code        date  total_vaccinations  \
# 43881  United States      USA  2021-01-01                 NaN
# 43882  United States      USA  2021-01-02           4225756.0
# 43883  United States      USA  2021-01-03                 NaN
# 43884  United States      USA  2021-01-04           4563260.0
# 43885  United States      USA  2021-01-05           4836469.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 43881                NaN                      NaN                     NaN
# 43882          4225756.0                      NaN                     NaN
# 43883                NaN                      NaN                     NaN
# 43884          4563260.0                      NaN                     NaN
# 43885          4836469.0                      NaN                273209.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 43881            302329.0                             NaN
# 43882            325882.0                            1.26
# 43883            336949.0                             NaN
# 43884            348017.0                            1.36
# 43885            339372.0                            1.44
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 43881                            NaN                                  NaN
# 43882                           1.26                                  NaN
# 43883                            NaN                                  NaN
# 43884                           1.36                                  NaN
# 43885                           1.44                                  NaN
#
#        daily_vaccinations_per_million  \
# 43881                           899.0
# 43882                           969.0
# 43883                          1002.0
# 43884                          1035.0
# 43885                          1009.0
#
#                                         vaccines  \
# 43881  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 43882  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 43883  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 43884  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 43885  Johnson&Johnson, Moderna, Pfizer/BioNTech
#
#                                       source_name  \
# 43881  Centers for Disease Control and Prevention
# 43882  Centers for Disease Control and Prevention
# 43883  Centers for Disease Control and Prevention
# 43884  Centers for Disease Control and Prevention
# 43885  Centers for Disease Control and Prevention
#
#                                           source_website
# 43881  https://covid.cdc.gov/covid-data-tracker/COVID...
# 43882  https://covid.cdc.gov/covid-data-tracker/COVID...
# 43883  https://covid.cdc.gov/covid-data-tracker/COVID...
# 43884  https://covid.cdc.gov/covid-data-tracker/COVID...
# 43885  https://covid.cdc.gov/covid-data-tracker/COVID...

# %% [markdown]
# We can also sort the DataFrame with a specific column as the key.

# %%
vaccine_df_usa_sorted_by_daily_vacs = vaccine_df_usa.sort_values('daily_vaccinations', ascending=False)
vaccine_df_usa_sorted_by_daily_vacs.head()
# Out:
#              country iso_code        date  total_vaccinations  \
# 43983  United States      USA  2021-04-13         192282781.0
# 43986  United States      USA  2021-04-16         202282923.0
# 43985  United States      USA  2021-04-15         198317040.0
# 43984  United States      USA  2021-04-14         194791836.0
# 43982  United States      USA  2021-04-12         189692045.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 43983        122295530.0               75322283.0               2590736.0
# 43986        127743096.0               80609818.0               3965883.0
# 43985        125822868.0               78498290.0               3525204.0
# 43984        123917385.0               76681252.0               2509055.0
# 43982        120848490.0               74066085.0               2644914.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 43983           3384387.0                           57.17
# 43986           3349306.0                           60.15
# 43985           3348189.0                           58.97
# 43984           3330740.0                           57.92
# 43982           3214893.0                           56.40
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 43983                          36.36                                22.40
# 43986                          37.98                                23.97
# 43985                          37.41                                23.34
# 43984                          36.84                                22.80
# 43982                          35.93                                22.02
#
#        daily_vaccinations_per_million  \
# 43983                         10063.0
# 43986                          9959.0
# 43985                          9955.0
# 43984                          9903.0
# 43982                          9559.0
#
#                                         vaccines  \
# 43983  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 43986  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 43985  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 43984  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 43982  Johnson&Johnson, Moderna, Pfizer/BioNTech
#
#                                       source_name  \
# 43983  Centers for Disease Control and Prevention
# 43986  Centers for Disease Control and Prevention
# 43985  Centers for Disease Control and Prevention
# 43984  Centers for Disease Control and Prevention
# 43982  Centers for Disease Control and Prevention
#
#                                           source_website
# 43983  https://covid.cdc.gov/covid-data-tracker/COVID...
# 43986  https://covid.cdc.gov/covid-data-tracker/COVID...
# 43985  https://covid.cdc.gov/covid-data-tracker/COVID...
# 43984  https://covid.cdc.gov/covid-data-tracker/COVID...
# 43982  https://covid.cdc.gov/covid-data-tracker/COVID...

# %% [markdown]
# ### 4. Useful Pandas Operations

# %% [markdown]
# View unique elements in a Series

# %%
vaccine_df['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Chile', 'China', 'Colombia',
#        'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', "Cote d'Ivoire",
#        'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czechia',
#        'Democratic Republic of Congo', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'England',
#        'Equatorial Guinea', 'Estonia', 'Eswatini', 'Ethiopia',
#        'Faeroe Islands', 'Falkland Islands', 'Fiji', 'Finland', 'France',
#        'French Polynesia', 'Gabon', 'Gambia', 'Georgia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
#        'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana',
#        'Haiti', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Isle of Man', 'Israel',
#        'Italy', 'Jamaica', 'Japan', 'Jersey', 'Jordan', 'Kazakhstan',
#        'Kenya', 'Kiribati', 'Kosovo', 'Kuwait', 'Kyrgyzstan', 'Laos',
#        'Latvia', 'Lebanon', 'Lesotho', 'Liberia', 'Libya',
#        'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macao', 'Madagascar',
#        'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Mauritania',
#        'Mauritius', 'Mexico', 'Moldova', 'Monaco', 'Mongolia',
#        'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar',
#        'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia',
#        'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue',
#        'North Macedonia', 'Northern Cyprus', 'Northern Ireland', 'Norway',
#        'Oman', 'Pakistan', 'Palestine', 'Panama', 'Papua New Guinea',
#        'Paraguay', 'Peru', 'Philippines', 'Pitcairn', 'Poland',
#        'Portugal', 'Qatar', 'Romania', 'Russia', 'Rwanda', 'Saint Helena',
#        'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'Samoa', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Scotland', 'Senegal',
#        'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South Korea',
#        'South Sudan', 'Spain', 'Sri Lanka', 'Sudan', 'Suriname', 'Sweden',
#        'Switzerland', 'Syria', 'Taiwan', 'Tajikistan', 'Tanzania',
#        'Thailand', 'Timor', 'Togo', 'Tokelau', 'Tonga',
#        'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan',
#        'Turks and Caicos Islands', 'Tuvalu', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela', 'Vietnam',
#        'Wales', 'Wallis and Futuna', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %% [markdown]
# View counts of items in a Series

# %%
vaccine_df['country'].value_counts()
# Out:
# Denmark         293
# Norway          292
# Latvia          291
# Scotland        286
# England         286
#                ...
# Haiti            64
# Tokelau          57
# Niue             43
# Tanzania         35
# Turkmenistan      1
# Name: country, Length: 222, dtype: int64

# %% [markdown]
# Add a column to a DataFrame

# %%
player_teams_df['Nationality'] = ['Argentina', 'Portugal', 'Brazil', 'France', 'Egypt']
player_teams_df
# Out:
#                                   Team  Age Nationality
# Name
# Lionel Messi       Paris Saint-Germain   34   Argentina
# Cristiano Ronaldo    Manchester United   36    Portugal
# Neymar             Paris Saint-Germain   29      Brazil
# Kylian Mbappe      Paris Saint-Germain   22      France
# Mohamed Salah                Liverpool   29       Egypt

# %% [markdown]
# Remove missing data

# %%
print(vaccine_df.shape)

# Remove rows where daily_vaccinations column has a missing entry
vaccine_df = vaccine_df.dropna(subset=['daily_vaccinations'])

print(vaccine_df.shape)
vaccine_df.head()
# Out:
# (45984, 15)
# (45677, 15)
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
# 5  Afghanistan      AFG  2021-02-27                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
# 5                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
# 5                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 1                                  NaN                            34.0
# 2                                  NaN                            34.0
# 3                                  NaN                            34.0
# 4                                  NaN                            34.0
# 5                                  NaN                            34.0
#
#                                             vaccines  \
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 5  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
#
#                  source_name  \
# 1  World Health Organization
# 2  World Health Organization
# 3  World Health Organization
# 4  World Health Organization
# 5  World Health Organization
#
#                                       source_website
# 1  https://app.powerbi.com/view?r=eyJrIjoiYTkyM2V...
# 2  https://app.powerbi.com/view?r=eyJrIjoiYTkyM2V...
# 3  https://app.powerbi.com/view?r=eyJrIjoiYTkyM2V...
# 4  https://app.powerbi.com/view?r=eyJrIjoiYTkyM2V...
# 5  https://app.powerbi.com/view?r=eyJrIjoiYTkyM2V...

# %% [markdown]
# Save DataFrame to CSV

# %%
vaccine_df.to_csv('data/covid_vaccinations/country_vaccinations_processed.csv', index=False)

# %%
player_teams_df.to_csv('data/player_teams.csv')
